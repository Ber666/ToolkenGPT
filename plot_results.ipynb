# %%
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
import pandas as pd
x = pd.DataFrame(np.array([[0.980, 0.592, 0.502, 0.212, 0.230 ], [0.970, 0.392, 0.242, 0.136, 0.208 ], [0.970, 0.320, 0.142, 0.126, 0.190 ], [ 0.932,0.254, 0.082, 0.056 , 0.190]]), columns=["ToolkenGPT (sup)", "ToolkenGPT (syn)", 'ICL', 'ICL (desc)','Prompting'], index=[30, 60, 100, 234])

# %%
x
# Out:
#      ToolkenGPT (sup)  ToolkenGPT (syn)    ICL  ICL (desc)  Prompting
# 30              0.980             0.592  0.502       0.212      0.230
# 60              0.970             0.392  0.242       0.136      0.208
# 100             0.970             0.320  0.142       0.126      0.190
# 234             0.932             0.254  0.082       0.056      0.190

# %%
from matplotlib import pyplot as plt

# create a lineplot
sns.set_theme(font_scale=1.8)
# sns.set(font_scale=1.5, style='ticks', palette='Set2', rc={'text.usetex': True})
sns.lineplot(data=x, markers=True, dashes=False)
plt.xticks([30, 60, 100, 234])
# plt.xticks(fontsize=15)
# save a high-res png in the current folder
# set x and y labels

plt.xlabel('Number of relations (used tools) in test set')
plt.ylabel('Accuracy')
# set the figure size
# plt.figure(figsize=(5, 5))

plt.savefig('results.png', dpi=300, bbox_inches='tight')
